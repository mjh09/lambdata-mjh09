# %%
import lambdata_mjh09.lambdata as lambdata
import pandas as pd

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -------------
# absl-py                            0.7.1
# aiohttp                            3.5.4
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# asn1crypto                         0.24.0
# astroid                            2.2.5
# astropy                            3.2.1
# async-timeout                      3.0.1
# atomicwrites                       1.3.0
# attrs                              19.1.0
# Babel                              2.7.0
# backcall                           0.1.0
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# beautifulsoup4                     4.7.1
# bitarray                           0.9.3
# bkcharts                           0.2
# bleach                             3.1.0
# bokeh                              1.2.0
# boto                               2.49.0
# Bottleneck                         1.2.1
# category-encoders                  1.3.0
# certifi                            2019.6.16
# cffi                               1.12.3
# chardet                            3.0.4
# Click                              7.0
# cloudpickle                        1.2.1
# clyent                             1.2.2
# colorama                           0.4.1
# comtypes                           1.1.7
# conda                              4.7.10
# conda-build                        3.17.8
# conda-package-handling             1.3.11
# conda-verify                       3.1.1
# contextlib2                        0.5.5
# cryptography                       2.7
# cycler                             0.10.0
# Cython                             0.29.12
# cytoolz                            0.10.0
# dask                               2.1.0
# decorator                          4.4.0
# defusedxml                         0.6.0
# distributed                        2.1.0
# docutils                           0.14
# eli5                               0.9.0
# entrypoints                        0.3
# enum34                             1.1.6
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# Flask                              1.1.1
# future                             0.17.1
# gevent                             1.4.0
# glob2                              0.7
# graphviz                           0.10.1
# greenlet                           0.4.15
# h5py                               2.9.0
# heapdict                           1.0.0
# html5lib                           1.0.1
# idna                               2.8
# imageio                            2.5.0
# imagesize                          1.1.0
# importlib-metadata                 0.17
# ipykernel                          5.1.1
# ipython                            7.6.1
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.0
# isort                              4.3.21
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.13.3
# Jinja2                             2.10.1
# joblib                             0.13.2
# json5                              0.8.4
# jsonschema                         3.0.1
# jupyter                            1.0.0
# jupyter-client                     5.3.1
# jupyter-console                    6.0.0
# jupyter-core                       4.5.0
# jupyterlab                         1.0.2
# jupyterlab-server                  1.0.0
# keyring                            18.0.0
# kiwisolver                         1.1.0
# lambdata-mjh09                     0.0.2
# lazy-object-proxy                  1.4.1
# libarchive-c                       2.8
# llvmlite                           0.29.0
# locket                             0.2.0
# lxml                               4.3.4
# MarkupSafe                         1.1.1
# matplotlib                         3.1.1
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.0.12
# mkl-random                         1.0.2
# mkl-service                        2.0.2
# mock                               3.0.5
# more-itertools                     7.0.0
# mpmath                             1.1.0
# mpyq                               0.2.5
# msgpack                            0.6.1
# multidict                          4.5.2
# multipledispatch                   0.6.0
# navigator-updater                  0.2.1
# nbconvert                          5.5.0
# nbformat                           4.4.0
# networkx                           2.3
# nltk                               3.4.4
# nose                               1.3.7
# notebook                           6.0.0
# numba                              0.44.1
# numexpr                            2.6.9
# numpy                              1.16.4
# numpydoc                           0.9.1
# olefile                            0.46
# openpyxl                           2.6.2
# packaging                          19.0
# pandas                             0.24.2
# pandocfilters                      1.4.2
# parso                              0.5.0
# partd                              1.0.0
# path.py                            12.0.1
# pathlib2                           2.3.4
# patsy                              0.5.1
# PDPbox                             0.2.0
# pep8                               1.7.1
# pickleshare                        0.7.5
# Pillow                             6.1.0
# pip                                19.2.1
# pipenv                             2018.11.26
# pkginfo                            1.5.0.1
# pluggy                             0.12.0
# ply                                3.11
# portpicker                         1.3.1
# prometheus-client                  0.7.1
# prompt-toolkit                     2.0.9
# protobuf                           3.8.0
# psutil                             5.6.3
# py                                 1.8.0
# pycodestyle                        2.5.0
# pycosat                            0.6.3
# pycparser                          2.19
# pycrypto                           2.6.1
# pycurl                             7.43.0.3
# pyflakes                           2.1.1
# pygame                             1.9.6
# pyglet                             1.3.2
# Pygments                           2.4.2
# pylint                             2.3.1
# pyodbc                             4.0.26
# pyOpenSSL                          19.0.0
# pyparsing                          2.4.0
# pyreadline                         2.1
# pyrsistent                         0.14.11
# PySC2                              2.0.2
# PySocks                            1.7.0
# pytest                             5.0.1
# pytest-arraydiff                   0.3
# pytest-astropy                     0.5.0
# pytest-doctestplus                 0.3.0
# pytest-openfiles                   0.3.2
# pytest-remotedata                  0.3.1
# python-dateutil                    2.8.0
# pytz                               2019.1
# PyWavelets                         1.0.3
# pywin32                            223
# pywinpty                           0.5.5
# PyYAML                             5.1.1
# pyzmq                              18.0.0
# QtAwesome                          0.5.7
# qtconsole                          4.5.1
# QtPy                               1.8.0
# requests                           2.22.0
# rope                               0.14.0
# ruamel-yaml                        0.15.46
# s2clientprotocol                   4.9.1.74456.0
# sc2                                0.11.1
# scikit-image                       0.15.0
# scikit-learn                       0.21.2
# scipy                              1.2.1
# seaborn                            0.9.0
# Send2Trash                         1.5.0
# setuptools                         41.0.1
# shap                               0.29.3
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# six                                1.12.0
# sk-video                           1.1.10
# snowballstemmer                    1.9.0
# sortedcollections                  1.1.2
# sortedcontainers                   2.1.0
# soupsieve                          1.8
# Sphinx                             2.1.2
# sphinxcontrib-applehelp            1.0.1
# sphinxcontrib-devhelp              1.0.1
# sphinxcontrib-htmlhelp             1.0.2
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.2
# sphinxcontrib-serializinghtml      1.1.3
# sphinxcontrib-websupport           1.1.2
# spyder                             3.3.6
# spyder-kernels                     0.5.1
# SQLAlchemy                         1.3.5
# statsmodels                        0.10.0
# sympy                              1.4
# tables                             3.5.2
# tabulate                           0.8.3
# tblib                              1.4.0
# terminado                          0.8.2
# testpath                           0.4.2
# toolz                              0.10.0
# tornado                            6.0.3
# tqdm                               4.32.1
# traitlets                          4.3.2
# typing                             3.6.4
# unicodecsv                         0.14.1
# urllib3                            1.24.2
# virtualenv                         16.7.2
# virtualenv-clone                   0.5.3
# wcwidth                            0.1.7
# webencodings                       0.5.1
# websocket-client                   0.56.0
# Werkzeug                           0.15.4
# wheel                              0.33.4
# whichcraft                         0.5.2
# widgetsnbextension                 3.5.0
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.11.2
# xlrd                               1.2.0
# XlsxWriter                         1.1.8
# xlwings                            0.15.8
# xlwt                               1.3.0
# yarl                               1.3.0
# zict                               1.0.0
# zipp                               0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
??lambdata

# %%
dir(lambdata)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'null',
#  'split_date']

# %%
SOURCE = 'C:/Users/Cactuar/Documents/'

# %%
rating_table = pd.read_csv(SOURCE + 'rating_table.csv')
match_table = pd.read_csv(SOURCE + 'match_table.csv')

# %%
match_table.head()
# Out:
#       id  period_id        date  pla_id  plb_id  sca  scb rca rcb treated  \
# 0  16039         37  2011-07-22      41     172    2    1   T   T       t
# 1  24883          2  2010-03-13     208    1218    4    2   Z   P       t
# 2  14085         42  2011-09-23     235     170    0    2   Z   P       t
# 3  81527         44  2011-10-24     130     721    2    0   Z   P       t
# 4  19393         29  2011-03-30     152      22    2    1   Z   Z       t
#
#                                                event  eventobj_id  \
# 0    ESET Summer Masters 2011 Q3 - Semi Final (SC2C)          NaN
# 1                                                NaN       7311.0
# 2  MLG Global Invitational NA - Loserbracket Prel...       3548.0
# 3                                                NaN      21686.0
# 4                                                NaN        982.0
#
#    submitter_id game offline     rta_id     rtb_id
# 0           NaN  WoL       f  4485977.0  4486087.0
# 1           NaN  WoL       f        NaN  1370384.0
# 2           NaN  WoL       f  4645786.0  4645732.0
# 3          10.0  WoL       f  4650861.0        NaN
# 4           NaN  WoL       t  4471621.0  4471523.0

# %%
rating_table.head()
# Out:
#         id  period_id  player_id    rating  rating_vp  rating_vt  rating_vz  \
# 0  6746817        243       1588  0.168328   0.000000   0.000000   0.000000
# 1  6746581        243       1320  0.162612   0.018065   0.022428  -0.040493
# 2  6746580        243       1319  0.012787   0.000000   0.000000   0.000000
# 3  6746579        243       1318 -0.049679   0.000000   0.000000   0.000000
# 4  6757453        243      13832 -0.138731   0.000000   0.090282  -0.090282
#
#     dev  dev_vp  dev_vt  ...  bf_dev_vp  bf_dev_vt  bf_dev_vz  position  \
# 0  0.16    0.16    0.16  ...       0.16       0.16       0.16       NaN
# 1  0.16    0.16    0.16  ...       0.16       0.16       0.16       NaN
# 2  0.16    0.16    0.16  ...       0.16       0.16       0.16       NaN
# 3  0.16    0.16    0.16  ...       0.16       0.16       0.16       NaN
# 4  0.16    0.16    0.16  ...       0.16       0.16       0.16       NaN
#
#    position_vp  position_vt  position_vz  decay  domination    prev_id
# 0          NaN          NaN          NaN    225         NaN  6729568.0
# 1          NaN          NaN          NaN      5         NaN  6729332.0
# 2          NaN          NaN          NaN    195         NaN  6729331.0
# 3          NaN          NaN          NaN    189         NaN  6729330.0
# 4          NaN          NaN          NaN     65         NaN  6740204.0
#
# [5 rows x 30 columns]

# %%
lambdata.null(rating_table)
# Out:
# id                    0
# period_id             0
# player_id             0
# rating                0
# rating_vp             0
# rating_vt             0
# rating_vz             0
# dev                   0
# dev_vp                0
# dev_vt                0
# dev_vz                0
# comp_rat              0
# comp_rat_vp           0
# comp_rat_vt           0
# comp_rat_vz           0
# bf_rating             0
# bf_rating_vp          0
# bf_rating_vt          0
# bf_rating_vz          0
# bf_dev                0
# bf_dev_vp             0
# bf_dev_vt             0
# bf_dev_vz             0
# position        1782929
# position_vp     1782929
# position_vt     1782929
# position_vz     1782929
# decay                 0
# domination      1794162
# prev_id           19801
# dtype: int64
